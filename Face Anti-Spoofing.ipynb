# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
import shutil
import os
for dirname, _, filenames in os.walk('/kaggle'):
    print (dirname)
# Out:
# /kaggle
# /kaggle/lib
# /kaggle/lib/kaggle
# /kaggle/lib/kaggle/competitions
# /kaggle/lib/kaggle/competitions/twosigmanews
# /kaggle/input
# /kaggle/input/real-and-fake-face-detection
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection/real_and_fake_face
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection/real_and_fake_face/training_fake
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection/real_and_fake_face/training_real
# /kaggle/config
# /kaggle/working
# /kaggle/working/.ipynb_checkpoints

# %%
# Configuration

DATASET_DIR = '/kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection/real_and_fake_face'
TRAIN_DIR = '/kaggle/train_dataset'
TEST_DIR = '/kaggle/test_dataset'

RATE = 0.2 # splitting proportion for training and test datasets

# %%
os.mkdir(TRAIN_DIR)
os.mkdir(TRAIN_DIR+'/fake')
os.mkdir(TRAIN_DIR+'/real')

os.mkdir(TEST_DIR)
os.mkdir(TEST_DIR+'/fake')
os.mkdir(TEST_DIR+'/real')

# %% [markdown]
# Updated folder structure:

# %%
for dirname, _, filenames in os.walk('/kaggle'):
    print (dirname)
# Out:
# /kaggle
# /kaggle/train_dataset
# /kaggle/train_dataset/fake
# /kaggle/train_dataset/real
# /kaggle/lib
# /kaggle/lib/kaggle
# /kaggle/lib/kaggle/competitions
# /kaggle/lib/kaggle/competitions/twosigmanews
# /kaggle/test_dataset
# /kaggle/test_dataset/fake
# /kaggle/test_dataset/real
# /kaggle/input
# /kaggle/input/real-and-fake-face-detection
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection/real_and_fake_face
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection/real_and_fake_face/training_fake
# /kaggle/input/real-and-fake-face-detection/real_and_fake_face_detection/real_and_fake_face/training_real
# /kaggle/config
# /kaggle/working
# /kaggle/working/.ipynb_checkpoints

# %%
# Split folders with images into training, validation and test folders.
# OPTION 1 (using split-folders)

#pip install split-folders

#import split_folders

# Split with a ratio.
# To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
#split_folders.ratio('input_folder', output="output", seed=1337, ratio=(.8, .1, .1)) # default values

# %%
# Split image files into test and training set 
# OPTION 2 (copying files into newly created folders)
files_real = os.listdir(f'{DATASET_DIR}/training_real')
files_fake = os.listdir(f'{DATASET_DIR}/training_fake')


# sample from each class to create a test set
np.random.seed(100)
files_real_test = np.random.choice(
    files_real,
    size=round(len(files_real) * RATE),
    replace=False,
    p=None)

files_real_train = list(set(files_real) - set(files_real_test)) #[file for file in files_real if file not in files_real_test] 

files_fake_test = np.random.choice(
    files_fake,
    size=round(len(files_fake) * RATE),
    replace=False,
    p=None)

files_fake_train = list(set(files_fake) - set(files_fake_test)) #[file for file in files_fake if file not in files_fake_test] 

[shutil.copyfile(DATASET_DIR+'/training_real/'+file, TRAIN_DIR+'/real/'+file)  
  for file in files_real_train]
[shutil.copyfile(DATASET_DIR+'/training_fake/'+file, TRAIN_DIR+'/fake/'+file)  
  for file in files_fake_train]

[shutil.copyfile(DATASET_DIR+'/training_real/'+file, TEST_DIR+'/real/'+file)  
  for file in files_real_test]
[shutil.copyfile(DATASET_DIR+'/training_fake/'+file, TEST_DIR+'/fake/'+file)  
  for file in files_fake_test]
# Out:
# ['/kaggle/test_dataset/fake/mid_338_1100.jpg',
#  '/kaggle/test_dataset/fake/hard_37_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_133_1001.jpg',
#  '/kaggle/test_dataset/fake/hard_19_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_205_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_459_1001.jpg',
#  '/kaggle/test_dataset/fake/easy_184_0110.jpg',
#  '/kaggle/test_dataset/fake/easy_18_0011.jpg',
#  '/kaggle/test_dataset/fake/hard_202_1101.jpg',
#  '/kaggle/test_dataset/fake/mid_406_0011.jpg',
#  '/kaggle/test_dataset/fake/hard_178_1001.jpg',
#  '/kaggle/test_dataset/fake/easy_27_1000.jpg',
#  '/kaggle/test_dataset/fake/easy_62_0001.jpg',
#  '/kaggle/test_dataset/fake/mid_34_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_147_1110.jpg',
#  '/kaggle/test_dataset/fake/hard_136_1101.jpg',
#  '/kaggle/test_dataset/fake/hard_94_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_139_0110.jpg',
#  '/kaggle/test_dataset/fake/easy_38_0010.jpg',
#  '/kaggle/test_dataset/fake/mid_16_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_409_1101.jpg',
#  '/kaggle/test_dataset/fake/mid_287_0001.jpg',
#  '/kaggle/test_dataset/fake/easy_3_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_424_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_383_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_377_0100.jpg',
#  '/kaggle/test_dataset/fake/easy_199_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_91_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_455_0101.jpg',
#  '/kaggle/test_dataset/fake/mid_73_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_232_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_395_1110.jpg',
#  '/kaggle/test_dataset/fake/easy_187_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_185_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_86_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_119_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_353_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_254_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_436_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_421_0011.jpg',
#  '/kaggle/test_dataset/fake/easy_164_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_80_0001.jpg',
#  '/kaggle/test_dataset/fake/mid_234_0010.jpg',
#  '/kaggle/test_dataset/fake/mid_191_0111.jpg',
#  '/kaggle/test_dataset/fake/easy_125_0011.jpg',
#  '/kaggle/test_dataset/fake/hard_61_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_174_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_228_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_60_1101.jpg',
#  '/kaggle/test_dataset/fake/hard_149_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_243_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_200_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_362_1101.jpg',
#  '/kaggle/test_dataset/fake/easy_111_1101.jpg',
#  '/kaggle/test_dataset/fake/mid_414_0011.jpg',
#  '/kaggle/test_dataset/fake/hard_164_1000.jpg',
#  '/kaggle/test_dataset/fake/hard_214_1011.jpg',
#  '/kaggle/test_dataset/fake/hard_171_1101.jpg',
#  '/kaggle/test_dataset/fake/easy_4_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_131_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_87_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_211_1100.jpg',
#  '/kaggle/test_dataset/fake/hard_152_0111.jpg',
#  '/kaggle/test_dataset/fake/mid_92_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_167_1100.jpg',
#  '/kaggle/test_dataset/fake/easy_123_0100.jpg',
#  '/kaggle/test_dataset/fake/easy_77_0111.jpg',
#  '/kaggle/test_dataset/fake/mid_23_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_30_1001.jpg',
#  '/kaggle/test_dataset/fake/mid_2_1101.jpg',
#  '/kaggle/test_dataset/fake/mid_351_0110.jpg',
#  '/kaggle/test_dataset/fake/mid_378_1110.jpg',
#  '/kaggle/test_dataset/fake/hard_27_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_298_0001.jpg',
#  '/kaggle/test_dataset/fake/easy_208_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_64_0010.jpg',
#  '/kaggle/test_dataset/fake/easy_226_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_12_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_16_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_145_1000.jpg',
#  '/kaggle/test_dataset/fake/mid_165_0101.jpg',
#  '/kaggle/test_dataset/fake/mid_101_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_434_1110.jpg',
#  '/kaggle/test_dataset/fake/hard_233_0010.jpg',
#  '/kaggle/test_dataset/fake/easy_161_1101.jpg',
#  '/kaggle/test_dataset/fake/easy_165_1010.jpg',
#  '/kaggle/test_dataset/fake/hard_224_0111.jpg',
#  '/kaggle/test_dataset/fake/mid_440_0101.jpg',
#  '/kaggle/test_dataset/fake/easy_126_0111.jpg',
#  '/kaggle/test_dataset/fake/mid_462_1101.jpg',
#  '/kaggle/test_dataset/fake/hard_114_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_96_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_40_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_9_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_57_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_179_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_200_1110.jpg',
#  '/kaggle/test_dataset/fake/easy_86_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_337_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_229_0100.jpg',
#  '/kaggle/test_dataset/fake/hard_126_0111.jpg',
#  '/kaggle/test_dataset/fake/hard_221_0101.jpg',
#  '/kaggle/test_dataset/fake/mid_252_1101.jpg',
#  '/kaggle/test_dataset/fake/mid_259_1101.jpg',
#  '/kaggle/test_dataset/fake/mid_255_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_391_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_237_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_162_0011.jpg',
#  '/kaggle/test_dataset/fake/easy_81_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_60_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_12_1101.jpg',
#  '/kaggle/test_dataset/fake/easy_63_1110.jpg',
#  '/kaggle/test_dataset/fake/easy_229_1000.jpg',
#  '/kaggle/test_dataset/fake/hard_138_1101.jpg',
#  '/kaggle/test_dataset/fake/hard_135_1101.jpg',
#  '/kaggle/test_dataset/fake/hard_74_0011.jpg',
#  '/kaggle/test_dataset/fake/easy_49_1000.jpg',
#  '/kaggle/test_dataset/fake/mid_134_1010.jpg',
#  '/kaggle/test_dataset/fake/hard_101_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_453_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_420_1101.jpg',
#  '/kaggle/test_dataset/fake/hard_161_1100.jpg',
#  '/kaggle/test_dataset/fake/hard_196_1101.jpg',
#  '/kaggle/test_dataset/fake/mid_46_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_111_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_178_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_206_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_150_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_417_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_212_0010.jpg',
#  '/kaggle/test_dataset/fake/hard_88_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_71_1100.jpg',
#  '/kaggle/test_dataset/fake/hard_185_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_248_0111.jpg',
#  '/kaggle/test_dataset/fake/mid_271_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_160_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_74_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_223_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_233_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_197_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_52_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_55_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_300_0111.jpg',
#  '/kaggle/test_dataset/fake/mid_365_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_69_1011.jpg',
#  '/kaggle/test_dataset/fake/mid_221_1100.jpg',
#  '/kaggle/test_dataset/fake/hard_26_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_222_1110.jpg',
#  '/kaggle/test_dataset/fake/easy_112_1001.jpg',
#  '/kaggle/test_dataset/fake/mid_463_0100.jpg',
#  '/kaggle/test_dataset/fake/easy_191_0001.jpg',
#  '/kaggle/test_dataset/fake/mid_258_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_94_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_173_1110.jpg',
#  '/kaggle/test_dataset/fake/hard_129_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_109_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_76_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_1_1110.jpg',
#  '/kaggle/test_dataset/fake/easy_58_0011.jpg',
#  '/kaggle/test_dataset/fake/easy_47_1110.jpg',
#  '/kaggle/test_dataset/fake/easy_239_1110.jpg',
#  '/kaggle/test_dataset/fake/easy_68_1100.jpg',
#  '/kaggle/test_dataset/fake/hard_13_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_36_1101.jpg',
#  '/kaggle/test_dataset/fake/easy_209_0001.jpg',
#  '/kaggle/test_dataset/fake/hard_28_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_75_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_371_0011.jpg',
#  '/kaggle/test_dataset/fake/mid_45_0010.jpg',
#  '/kaggle/test_dataset/fake/mid_336_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_47_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_145_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_260_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_190_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_411_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_170_0010.jpg',
#  '/kaggle/test_dataset/fake/mid_274_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_231_1100.jpg',
#  '/kaggle/test_dataset/fake/mid_324_1111.jpg',
#  '/kaggle/test_dataset/fake/easy_118_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_403_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_321_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_61_1111.jpg',
#  '/kaggle/test_dataset/fake/hard_232_0001.jpg',
#  '/kaggle/test_dataset/fake/mid_405_0011.jpg',
#  '/kaggle/test_dataset/fake/easy_39_0011.jpg',
#  '/kaggle/test_dataset/fake/easy_147_1110.jpg',
#  '/kaggle/test_dataset/fake/mid_143_1100.jpg',
#  '/kaggle/test_dataset/fake/easy_41_0001.jpg',
#  '/kaggle/test_dataset/fake/mid_250_1111.jpg',
#  '/kaggle/test_dataset/fake/mid_399_0011.jpg',
#  '/kaggle/test_dataset/fake/hard_165_1000.jpg']
